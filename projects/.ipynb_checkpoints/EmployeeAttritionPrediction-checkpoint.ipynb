# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Classification

# %%
df = pd.read_csv('hr_data.csv')

# %% [markdown]
# # EDA-Exploratory Data Analysis

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
df.sample(5)
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 1319   32  Travel_Frequently       1318                   Sales
# 306    32      Travel_Rarely        906                   Sales
# 1229   40      Travel_Rarely        369  Research & Development
# 178    46      Travel_Rarely        526                   Sales
# 854    45      Travel_Rarely       1457  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1319                10          4      Marketing              1
# 306                  7          3  Life Sciences              1
# 1229                 8          2  Life Sciences              1
# 178                  1          2      Marketing              1
# 854                  7          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 1319            1853                        4    Male          79
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1020
# Yes     185
# Name: count, dtype: int64

# %%
df.Attrition.value_counts()
# Out:
# Attrition
# No     1020
# Yes     185
# Name: count, dtype: int64

# %%
dc={'Yes':1,'No':0}
df['Attrition'] = df['Attrition'].map(dc)

# %%
filled = filled=df[df.Attrition.notnull()]

# %%
filled.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
filled.shape
# Out:
# (1205, 35)

# %%
notfilled =df[df.Attrition.isnull()]

# %%
notfilled.head()
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 367   50  Travel_Rarely       1046  Research & Development                10
# 368   40  Travel_Rarely        575                   Sales                22
# 369   31  Travel_Rarely        408  Research & Development                 9
# 370   21  Travel_Rarely        156                   Sales                12
# 371   29  Travel_Rarely       1283  Research & Development                23
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  \
# 367          3  Technical Degree              1             491
# 368          2         Marketing              1             492
# 369          4     Life Sciences              1             493
# 370          3     Life Sciences              1             494
# 371          3     Life Sciences              1             495
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
sns.countplot(x=df['Attrition'], data=df, hue="Attrition")
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
x=filled.drop('Attrition', axis=1)
y= filled['Attrition']

# %%
x.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
sns.countplot(x=x['BusinessTravel'], data=df, hue="BusinessTravel")
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(x=x['Department'], data=df, hue="Department")
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.countplot(x=x['EducationField'], data=df,hue="EducationField" )
# Out:
# <Axes: xlabel='EducationField', ylabel='count'>

# %%
x=pd.get_dummies(x, drop_first= True)

# %%
x.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

# %%
g = GaussianNB()
b = BernoulliNB()

# %%
g.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
b.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
predg=g.predict(x_test)
predb=b.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
accuracy_score(predg, y_test)
# Out:
# 0.7883817427385892

# %%
accuracy_score(predb, y_test)
# Out:
# 0.8257261410788381

# %%
confusion_matrix(predb, y_test)
# Out:
# array([[192,  23],
#        [ 19,   7]])

# %%
sns.heatmap(confusion_matrix(predb, y_test), annot=True)
# Out:
# <Axes: >

# %%
confusion_matrix(predg, y_test)
# Out:
# array([[171,  11],
#        [ 40,  19]])

# %%
#  Probability
# Cosine Distance
# Tree
# Ensemble/ Forest

# %%
from sklearn.linear_model import LogisticRegression

# %%
l = LogisticRegression()
l.fit(x_train, y_train)
predl= l.predict(x_test)
accuracy_score(predl, y_test)
# Out:
# 0.8672199170124482

# %%
confusion_matrix(predl, y_test)
# Out:
# array([[209,  30],
#        [  2,   0]])

# %%
print(classification_report(predl,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.93       239
#          1.0       0.00      0.00      0.00         2
#
#     accuracy                           0.87       241
#    macro avg       0.50      0.44      0.46       241
# weighted avg       0.98      0.87      0.92       241

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d = DecisionTreeClassifier()
d.fit(x_train, y_train)
predd= d.predict(x_test)
accuracy_score(predd, y_test)
# Out:
# 0.8008298755186722

# %%
confusion_matrix(predd, y_test)
# Out:
# array([[183,  20],
#        [ 28,  10]])

# %%
print(classification_report(predd,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88       203
#          1.0       0.33      0.26      0.29        38
#
#     accuracy                           0.80       241
#    macro avg       0.60      0.58      0.59       241
# weighted avg       0.78      0.80      0.79       241

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
predrf= rf.predict(x_test)
accuracy_score(predrf, y_test)
# Out:
# 0.8921161825726142

# %%
confusion_matrix(predrf, y_test)
# Out:
# array([[211,  26],
#        [  0,   4]])

# %%
print(classification_report(predrf,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94       237
#          1.0       0.13      1.00      0.24         4
#
#     accuracy                           0.89       241
#    macro avg       0.57      0.95      0.59       241
# weighted avg       0.99      0.89      0.93       241

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gr = GradientBoostingClassifier()
gr.fit(x_train, y_train)
predgr= gr.predict(x_test)
accuracy_score(predgr, y_test)
# Out:
# 0.8879668049792531

# %%
confusion_matrix(predgr, y_test)
# Out:
# array([[208,  24],
#        [  3,   6]])

# %%
print(classification_report(predgr,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.90      0.94       232
#          1.0       0.20      0.67      0.31         9
#
#     accuracy                           0.89       241
#    macro avg       0.59      0.78      0.62       241
# weighted avg       0.96      0.89      0.92       241

# %%
#Extra Gradient Boosting - Deep Learning

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
y_train
# Out:
# 294     0.0
# 976     0.0
# 405     1.0
# 702     0.0
# 1048    0.0
#        ...
# 1186    1.0
# 1237    1.0
# 1369    1.0
# 960     0.0
# 1365    1.0
# Name: Attrition, Length: 964, dtype: float64

# %%
xb = XGBClassifier()
xb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
predxb= xb.predict(x_test)
accuracy_score(predxb, y_test)
# Out:
# 0.8962655601659751

# %%
confusion_matrix(predxb, y_test)
# Out:
# array([[206,  20],
#        [  5,  10]])

# %%
print(classification_report(predgr,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.90      0.94       232
#          1.0       0.20      0.67      0.31         9
#
#     accuracy                           0.89       241
#    macro avg       0.59      0.78      0.62       241
# weighted avg       0.96      0.89      0.92       241

# %%
#SVM-Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(x_train, y_train)
predsvc= svc.predict(x_test)
accuracy_score(predsvc, y_test)
# Out:
# 0.8755186721991701

# %%
print(classification_report(predsvc,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.88      0.93       241
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.88       241
#    macro avg       0.50      0.44      0.47       241
# weighted avg       1.00      0.88      0.93       241

# %%
xb.fit(x,y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
pred=xb.predict(x)

# %%
accuracy_score(pred,y)
# Out:
# 1.0

# %%
newx = notfilled.drop('Attrition', axis=1)

# %%
newx = pd.get_dummies(newx,drop_first=True )

# %%
prediction = xb. predict(newx)

# %%
notfilled['Attrition']= prediction

# %%
df2 = pd.concat([filled, notfilled], ignore_index=True)

# %%
df2.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
di ={1.0:'Yes', 0.0:'No'}
df2['Attrition']= df2['Attrition'].map(di)

# %%
df2.to_csv('hr_data_missingfilled.csv')

# %%
result = pd.read_csv('hr_data.csv')

# %%
result.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ### Classification using SMOTE

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
x_smote, y_smote = oversample.fit_resample(x, y)

# %%
x_train, x_test, y_train, y_test = train_test_split( x_smote, y_smote, test_size = 0.20, random_state = 42)

# %%
g = GaussianNB()
b = BernoulliNB()
g.fit(x_train, y_train)
b.fit(x_train, y_train)
predg=g.predict(x_test)
predb=b.predict(x_test)
accuracy_score(predg, y_test)
# Out:
# 1.0

# %%
accuracy_score(predb, y_test)
# Out:
# 0.3

# %%
def classification_funct(x,y):
    from sklearn.naive_bayes import GaussianNB
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.svm import SVC
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.linear_model import LogisticRegression
    
    from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
    from sklearn.metrics import confusion_matrix,classification_report
       
    oversample = SMOTE()
    x_smote, y_smote = oversample.fit_resample(x, y)
    x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.2,random_state=42)
       
    g=GaussianNB()
    b=BernoulliNB()
    D=DecisionTreeClassifier()
    R=RandomForestClassifier()
    Log=LogisticRegression()
    
    algos=[g,b,D,R,Log]
    algo_names=['GaussianNB','BernoulliNB','DecisionTreeClassifier','RandomForestClassifier','LogisticRegression']
    
    accuracy_scored=[]
    precision_scored=[]
    recall_scored=[]
    f1_scored=[]
    
    for item in algos:
        predict=item.fit(x_train,y_train).predict(x_test)
        print("\n {} confusion_matrix".format(item))
        print(confusion_matrix(y_test,item.predict(x_test)))

        accuracy_scored.append(accuracy_score(y_test,item.predict(x_test)))
        precision_scored.append(precision_score(y_test,predict, average='micro'))
        recall_scored.append(recall_score(y_test,predict,average='micro'))
        f1_scored.append(f1_score(y_test,predict,average='micro'))
      
    result=pd.DataFrame(columns=['f1_score','accuracy_score'],index=algo_names)
    result['accuracy_score']=accuracy_scored
    result['f1_score']=f1_scored
    result['recall_score']=recall_scored
    result['precision_score']=precision_scored

    classification_funct.result=result.sort_values('accuracy_score',ascending=False)
    return result.sort_values('accuracy_score',ascending=False)

# %%
classification_funct(x,y)
# Out:
#  GaussianNB() confusion_matrix
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#
#  BernoulliNB() confusion_matrix
# [[ 0 10  0]
#  [ 0  9  0]
#  [ 0 11  0]]
#
#  DecisionTreeClassifier() confusion_matrix
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#
#  RandomForestClassifier() confusion_matrix
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#
#  LogisticRegression() confusion_matrix
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#                         f1_score  accuracy_score  recall_score  \
# GaussianNB                   1.0             1.0           1.0
# DecisionTreeClassifier       1.0             1.0           1.0
# RandomForestClassifier       1.0             1.0           1.0
# LogisticRegression           1.0             1.0           1.0
# BernoulliNB                  0.3             0.3           0.3
#
#                         precision_score
# GaussianNB                          1.0
# DecisionTreeClassifier              1.0
# RandomForestClassifier              1.0
# ...
