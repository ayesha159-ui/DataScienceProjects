# %% [markdown]
# ## **Download Important Libraries**

# %%
# !pip install spark
# Out:
# Requirement already satisfied: spark in c:\users\ayesh\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: pydantic<3.0,>=2.7 in c:\users\ayesh\anaconda3\lib\site-packages (from spark) (2.10.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in c:\users\ayesh\anaconda3\lib\site-packages (from spark) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ayesh\anaconda3\lib\site-packages (from pydantic<3.0,>=2.7->spark) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ayesh\anaconda3\lib\site-packages (from pydantic<3.0,>=2.7->spark) (2.27.1)

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 4.0.1

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pyspark.ml.classification import GBTClassifier
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, VectorIndexer
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors
from pyspark.sql import SparkSession
from pyspark.sql import Row
import collections
from pyspark import SparkConf,SparkContext


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df = pd.read_csv("data/churn.csv")

# %%
df.head()
# Out:
#    Unnamed: 0             Names   Age  Total_Purchase  Account_Manager  Years  \
# 0           0  Cameron Williams  42.0        11066.80                0   7.22
# 1           1     Kevin Mueller  41.0        11916.22                0   6.50
# 2           2       Eric Lozano  38.0        12884.75                0   6.67
# 3           3     Phillip White  42.0         8010.76                0   6.71
# 4           4    Cynthia Norton  37.0         9191.58                0   5.56
#
#    Num_Sites  Churn
# 0        8.0      1
# 1       11.0      1
# 2       12.0      1
# 3       10.0      1
# 4        9.0      1

# %%
df.tail()
# Out:
#      Unnamed: 0            Names   Age  Total_Purchase  Account_Manager  \
# 895         895      Paul Miller  42.0        12800.82                1
# 896         896   Natalie Hodges  52.0         9893.92                0
# 897         897        Ana Smith  45.0        12056.18                0
# 898         898   Justin Leonard  51.0         6517.93                1
# 899         899  Joseph Williams  39.0         9315.60                1
#
#      Years  Num_Sites  Churn
# 895   3.62        8.0      0
# 896   6.91        7.0      0
# 897   5.46        4.0      0
# 898   5.47       10.0      0
# 899   5.02       10.0      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       900 non-null    int64
#  1   Names            900 non-null    object
#  2   Age              900 non-null    float64
#  3   Total_Purchase   900 non-null    float64
#  4   Account_Manager  900 non-null    int64
#  5   Years            900 non-null    float64
#  6   Num_Sites        900 non-null    float64
#  7   Churn            900 non-null    int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 56.4+ KB

# %%
df.nunique()
# Out:
# Unnamed: 0         900
# Names              899
# Age                 36
# Total_Purchase     900
# Account_Manager      2
# Years              418
# Num_Sites           12
# Churn                2
# dtype: int64

# %%
df.shape
# Out:
# (900, 8)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Names              0
# Age                0
# Total_Purchase     0
# Account_Manager    0
# Years              0
# Num_Sites          0
# Churn              0
# dtype: int64

# %%
df.describe().T
# Out:
#                  count          mean          std    min        25%  \
# Unnamed: 0       900.0    449.500000   259.951919    0.0   224.7500
# Age              900.0     41.816667     6.127560   22.0    38.0000
# Total_Purchase   900.0  10062.824033  2408.644532  100.0  8497.1225
# Account_Manager  900.0      0.481111     0.499921    0.0     0.0000
# Years            900.0      5.273156     1.274449    1.0     4.4500
# Num_Sites        900.0      8.587778     1.764836    3.0     7.0000
# Churn            900.0      0.166667     0.372885    0.0     0.0000
#
#                        50%        75%       max
# Unnamed: 0         449.500    674.250    899.00
# Age                 42.000     46.000     65.00
# Total_Purchase   10045.870  11760.105  18026.01
# Account_Manager      0.000      1.000      1.00
# Years                5.215      6.110      9.15
# Num_Sites            8.000     10.000     14.00
# Churn                0.000      0.000      1.00

# %%
df.count()
# Out:
# Unnamed: 0         900
# Names              900
# Age                900
# Total_Purchase     900
# Account_Manager    900
# Years              900
# Num_Sites          900
# Churn              900
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                  Unnamed: 0       Age  Total_Purchase  Account_Manager  \
# Unnamed: 0         1.000000 -0.037801       -0.018938        -0.067247
# Age               -0.037801  1.000000       -0.037208        -0.014749
# Total_Purchase    -0.018938 -0.037208        1.000000         0.015856
# Account_Manager   -0.067247 -0.014749        0.015856         1.000000
# Years             -0.143873  0.005625       -0.005623         0.022930
# Num_Sites         -0.378287 -0.006070       -0.003390         0.033401
# Churn             -0.645498  0.085926        0.024031         0.070611
#
#                     Years  Num_Sites     Churn
# Unnamed: 0      -0.143873  -0.378287 -0.645498
# Age              0.005625  -0.006070  0.085926
# Total_Purchase  -0.005623  -0.003390  0.024031
# Account_Manager  0.022930   0.033401  0.070611
# Years            1.000000   0.051642  0.214329
# Num_Sites        0.051642   1.000000  0.525398
# Churn            0.214329   0.525398  1.000000

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(df,hue="Churn");

# %%
sns.pairplot(df,hue="Churn", kind="reg");

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Engineering

# %%
df.drop(['Unnamed: 0','Names'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Age  Total_Purchase  Account_Manager  Years  Num_Sites  Churn
# 0  42.0        11066.80                0   7.22        8.0      1
# 1  41.0        11916.22                0   6.50       11.0      1
# 2  38.0        12884.75                0   6.67       12.0      1
# 3  42.0         8010.76                0   6.71       10.0      1
# 4  37.0         9191.58                0   5.56        9.0      1

# %%
 df['Account_Manager']=df['Account_Manager'].astype(float)
 df['Churn']=df['Churn'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              900 non-null    float64
#  1   Total_Purchase   900 non-null    float64
#  2   Account_Manager  900 non-null    float64
#  3   Years            900 non-null    float64
#  4   Num_Sites        900 non-null    float64
#  5   Churn            900 non-null    float64
# dtypes: float64(6)
# memory usage: 42.3 KB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Linear Regression

# %%
x=df.drop('Churn',axis=1)
y=df['Churn']

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.20, random_state = 42)

# %%
lr=LinearRegression()
model = lr.fit(x_train, y_train)
pred = model.predict(x_test)

# %%
r2_score(pred, y_test)
# Out:
# -1.187979067874409

# %%
mean_squared_error(pred,y_test)**0.5
# Out:
# 0.3172029903509226

# %% [markdown]
# ## Random Forest Regression

# %%
regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)
regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=0)

# %%
pred = regressor.predict(x_test)

# %%
r2_score(pred, y_test)
# Out:
# 0.8440506208099807

# %%
mean_squared_error(pred,y_test)**0.5
# Out:
# 0.1269295517643985

# %% [markdown]
# # Pyspark

# %%
from __future__ import print_function
spark=SparkSession.builder.getOrCreate()
inputlines=df = spark.read.options(header = True, inferSchema = True).csv("data/churn.csv")
inputlines
# Out:
# DataFrame[_c0: int, Names: string, Age: double, Total_Purchase: double, Account_Manager: int, Years: double, Num_Sites: double, Churn: int]

# %%
df=inputlines.rdd.map(lambda x: x.split(","))

# %%
df
# Out:
# PythonRDD[15] at RDD at PythonRDD.scala:56

# %%
col=['Age','Total_Purchase','Account_Manager','Years','Num_Sites','Churn']
df1 = inputlines
df1
# Out:
# DataFrame[_c0: int, Names: string, Age: double, Total_Purchase: double, Account_Manager: int, Years: double, Num_Sites: double, Churn: int]

# %%
from  pyspark.ml.feature import VectorAssembler
vecAssembler = VectorAssembler(inputCols=['Age','Total_Purchase','Account_Manager','Years','Num_Sites'], outputCol="features")
df1= vecAssembler.transform(df1)
df1
# Out:
# DataFrame[_c0: int, Names: string, Age: double, Total_Purchase: double, Account_Manager: int, Years: double, Num_Sites: double, Churn: int, features: vector]

# %%
df1 = df1.drop("index",'Names', 'Age','Total_Purchase','Account_Manager','Years','Num_Sites')
df1
# Out:
# DataFrame[_c0: int, Churn: int, features: vector]

# %%
df1 = df1.withColumnRenamed("Churn", "label")
df1.head()
# Out:
# Row(_c0=0, label=1, features=DenseVector([42.0, 11066.8, 0.0, 7.22, 8.0]))

# %%
df1.show()
# Out:
# +---+-----+--------------------+
# |_c0|label|            features|
# +---+-----+--------------------+
# |  0|    1|[42.0,11066.8,0.0...|
# |  1|    1|[41.0,11916.22,0....|
# |  2|    1|[38.0,12884.75,0....|
# |  3|    1|[42.0,8010.76,0.0...|
# |  4|    1|[37.0,9191.58,0.0...|
# |  5|    1|[48.0,10356.02,0....|
# |  6|    1|[44.0,11331.58,1....|
# |  7|    1|[32.0,9885.12,1.0...|
# |  8|    1|[43.0,14062.6,1.0...|
# |  9|    1|[40.0,8066.94,1.0...|
# | 10|    1|[30.0,11575.37,1....|
# | 11|    1|[45.0,8771.02,1.0...|
# | 12|    1|[45.0,8988.67,1.0...|
# | 13|    1|[40.0,8283.32,1.0...|
# | 14|    1|[41.0,6569.87,1.0...|
# | 15|    1|[38.0,10494.82,1....|
# | 16|    1|[45.0,8213.41,1.0...|
# | 17|    1|[43.0,11226.88,0....|
# | 18|    1|[53.0,5515.09,0.0...|
# | 19|    1|[46.0,8046.4,1.0,...|
# +---+-----+--------------------+
# only showing top 20 rows

# %%
trainTestSplit=df1.randomSplit([0.5,0.5])
train=trainTestSplit[0]
test=trainTestSplit[1]
train
# Out:
# DataFrame[_c0: int, label: int, features: vector]

# %%
test
# Out:
# DataFrame[_c0: int, label: int, features: vector]

# %% [markdown]
# # GBT Classifier

# %%
gbt=GBTClassifier(featuresCol='features',maxIter=10)
gbt = gbt.fit(train)

# %%
predictions = gbt.transform(test)
predictions.show()
# Out:
# +---+-----+--------------------+--------------------+--------------------+----------+
# |_c0|label|            features|       rawPrediction|         probability|prediction|
# +---+-----+--------------------+--------------------+--------------------+----------+
# |  0|    1|[42.0,11066.8,0.0...|[1.29362169079517...|[0.93003605924921...|       0.0|
# |  1|    1|[41.0,11916.22,0....|[-0.2668938204704...|[0.36963391501375...|       1.0|
# |  3|    1|[42.0,8010.76,0.0...|[-0.8012006312446...|[0.16764627283215...|       1.0|
# |  4|    1|[37.0,9191.58,0.0...|[1.13443124524042...|[0.90626520258337...|       0.0|
# |  7|    1|[32.0,9885.12,1.0...|[0.96270438717975...|[0.87274036921029...|       0.0|
# |  9|    1|[40.0,8066.94,1.0...|[-1.1839472728875...|[0.08565388913952...|       1.0|
# | 11|    1|[45.0,8771.02,1.0...|[0.17951178430714...|[0.58880404702132...|       0.0|
# | 12|    1|[45.0,8988.67,1.0...|[-0.2213007533563...|[0.39112125716324...|       1.0|
# | 13|    1|[40.0,8283.32,1.0...|[-1.3167978198383...|[0.06700731051774...|       1.0|
# | 14|    1|[41.0,6569.87,1.0...|[-0.7871957236682...|[0.17159125704788...|       1.0|
# | 15|    1|[38.0,10494.82,1....|[-1.3096588606796...|[0.06790546520577...|       1.0|
# | 16|    1|[45.0,8213.41,1.0...|[-0.3154377106423...|[0.34731206519608...|       1.0|
# | 17|    1|[43.0,11226.88,0....|[-0.2909377519775...|[0.35850115450314...|       1.0|
# | 18|    1|[53.0,5515.09,0.0...|[1.33203447479272...|[0.93487284584840...|       0.0|
# | 21|    1|[56.0,12217.95,1....|[-1.1459041303700...|[0.09180367349465...|       1.0|
# | 26|    1|[35.0,12403.81,0....|[0.86109261363424...|[0.84841009333598...|       0.0|
# | 27|    1|[40.0,10041.13,0....|[-0.4566745456147...|[0.28631499876694...|       1.0|
# | 28|    1|[44.0,12721.55,0....|[0.35923497319017...|[0.67226999988951...|       0.0|
# | 34|    1|[48.0,11740.0,1.0...|[-0.3215746947330...|[0.34453496299692...|       1.0|
# | 35|    1|[37.0,14383.36,0....|[-0.0675044111695...|[0.46629896900170...|       1.0|
# +---+-----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8724373576309795

# %% [markdown]
# ### Evaluation using ROC-AUC and accuracy metrics

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator

# ROC-AUC (area under ROC)
e_auc = BinaryClassificationEvaluator(
    labelCol="label",
    rawPredictionCol="rawPrediction",   # or probabilityCol if you prefer
    metricName="areaUnderROC"
)
roc_auc = e_auc.evaluate(predictions)

# Accuracy
e_acc = MulticlassClassificationEvaluator(
    labelCol="label",
    predictionCol="prediction",
    metricName="accuracy"
)
accuracy = e_acc.evaluate(predictions)

print(f"ROC-AUC: {roc_auc:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# ROC-AUC: 0.8682
# Accuracy: 0.8724

# %%
e_pr = BinaryClassificationEvaluator(
    labelCol="label",
    rawPredictionCol="rawPrediction",
    metricName="areaUnderPR"
)
pr_auc = e_pr.evaluate(predictions)
print(f"PR-AUC: {pr_auc:.4f}")
# Out:
# PR-AUC: 0.6297

# %%
e_f1 = MulticlassClassificationEvaluator(
    labelCol="label", predictionCol="prediction", metricName="f1"
)
e_wp = MulticlassClassificationEvaluator(
    labelCol="label", predictionCol="prediction", metricName="weightedPrecision"
)
e_wr = MulticlassClassificationEvaluator(
    labelCol="label", predictionCol="prediction", metricName="weightedRecall"
)

f1  = e_f1.evaluate(predictions)
wp  = e_wp.evaluate(predictions)
wr  = e_wr.evaluate(predictions)

print(f"F1 (weighted): {f1:.4f}")
print(f"Precision (weighted): {wp:.4f}")
print(f"Recall (weighted): {wr:.4f}")
# Out:
# F1 (weighted): 0.8679
# Precision (weighted): 0.8654
# Recall (weighted): 0.8724

# %%
# counts for (label, prediction)
from pyspark.sql.functions import col

conf = (
    predictions.groupBy(col("label"), col("prediction"))
         .count()
         .orderBy("label", "prediction")
)
conf.show()
# Out:
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    0|       0.0|  342|
# |    0|       1.0|   22|
# |    1|       0.0|   34|
# |    1|       1.0|   41|
# +-----+----------+-----+

# %%
conf_pivot = (
    predictions.groupBy(col("label"))
         .pivot("prediction", [0.0, 1.0])
         .count()
         .na.fill(0)
)
conf_pivot.show()
# Out:
# +-----+---+---+
# |label|0.0|1.0|
# +-----+---+---+
# |    1| 34| 41|
# |    0|342| 22|
# +-----+---+---+
